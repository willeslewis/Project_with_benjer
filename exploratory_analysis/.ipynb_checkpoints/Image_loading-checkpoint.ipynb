# %%
import sys
sys.path.insert(0,'..')
import pydicom
import matplotlib.pyplot as plt
import numpy as np
from skimage import io

# %%
# %%timeit
image_path = '/Users/William/Desktop/Kaggle_Competitions/Project_with_benjer/kaggle_data/all/stage_1_train_images/'
image = pydicom.dcmread(image_path+'010ccb9f-6d46-4380-af11-84f87397a1b8.dcm')
# Out:
# 897 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
image_path = '/Users/William/Desktop/Kaggle_Competitions/Project_with_benjer/kaggle_data/all/stage_1_train_images/'
image = pydicom.dcmread(image_path+'010ccb9f-6d46-4380-af11-84f87397a1b8.dcm')
image
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.7487.1517874331.853501
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '010ccb9f-6d46-4380-af11-84f87397a1b8'
# (0010, 0020) Patient ID                          LO: '010ccb9f-6d46-4380-af11-84f87397a1b8'
# (0010, 0030) Patient's Birth Date                DA: ''
# ...

# %%
# %%timeit
image.pixel_array
# Out:
# 6.27 µs ± 81.5 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
plt.imshow(image.pixel_array, cmap=plt.cm.bone)
plt.show()

# %%
# %%timeit
proshot = io.imread('/Users/William/Desktop/TDI/ResumeTips/Web_Resolution_copy.jpg')
# Out:
# 88.6 ms ± 1.28 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
proshot = io.imread('/Users/William/Desktop/TDI/ResumeTips/Web_Resolution_copy.jpg')
plt.imshow(proshot, cmap=plt.cm.bone)
plt.show()

# %% [markdown]
# ## It doesn't look like we need to save the data as a different format. The conversion from dicom to np array is fast compared to image import calls. I'm going to make a dicom module where we can start to collect functions that take in a file name and output a numpy array corresponding to any preprocessing we do.

# %%
import sys
from utils import improcess as ip

# %%
image_name='010ccb9f-6d46-4380-af11-84f87397a1b8.dcm'
plt.imshow(ip.dicom_to_array(image_path,image_name), cmap=plt.cm.bone)
plt.show()

# %%
#make sure that my function works as expected
check_equality = np.sum((image.pixel_array) == ip.dicom_to_array(image_path,image_name)) 
check_equality == image.pixel_array.size
# Out:
# True

# %% [markdown]
# ## Note that I'm not sure yet exactly how kaggle submission works. We will need to see what model upload requirements look like. It may not make sense to utilize a new library of functions we make, but we'll see.
#
# Also, in order to import the utils module, I need to explicitly add the directory to the sys path. This will work for now, but is not ideal.

# %%
ip.dicom_to_normalized_array(image_path,image_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-a1e272e7cdab> in <module>()
# ----> 1 ip.dicom_to_normalized_array(image_path,image_name)
#
# AttributeError: module 'utils.improcess' has no attribute 'dicom_to_normalized_array'
